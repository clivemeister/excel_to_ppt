# %%
import matplotlib.pyplot as plt
vals=[0.27,0.15,0.23]

plt.title('Synergy',size=24)
plt.annotate("June\n27%",xy=(0.1,0.25),size=16)
plt.annotate("Aug\n23%",xy=(2,0.21),size=16)
plt.axis('off')
plt.plot(vals,color='#009000',linewidth=3)
plt.show()
